# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('Property_stolen_and_recovered.csv')
data
# Out:
#                       Area_Name  Year           Group_Name  \
# 0     Andaman & Nicobar Islands  2001  Burglary - Property
# 1                Andhra Pradesh  2001  Burglary - Property
# 2             Arunachal Pradesh  2001  Burglary - Property
# 3                         Assam  2001  Burglary - Property
# 4                         Bihar  2001  Burglary - Property
# ...                         ...   ...                  ...
# 2444                 Tamil Nadu  2010       Total Property
# 2445                    Tripura  2010       Total Property
# 2446              Uttar Pradesh  2010       Total Property
# 2447                Uttarakhand  2010       Total Property
# 2448                West Bengal  2010       Total Property
#
#                             Sub_Group_Name  Cases_Property_Recovered  \
# 0                              3. Burglary                        27
# 1                              3. Burglary                      3321
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2449 entries, 0 to 2448
# Data columns (total 8 columns):
# Area_Name                      2449 non-null object
# Year                           2449 non-null int64
# Group_Name                     2449 non-null object
# Sub_Group_Name                 2449 non-null object
# Cases_Property_Recovered       2449 non-null int64
# Cases_Property_Stolen          2449 non-null int64
# Value_of_Property_Recovered    2449 non-null int64
# Value_of_Property_Stolen       2449 non-null int64
# dtypes: int64(5), object(3)
# memory usage: 153.2+ KB

# %%
data.describe()
# Out:
#               Year  Cases_Property_Recovered  Cases_Property_Stolen  \
# count  2449.000000               2449.000000            2449.000000
# mean   2005.499388               1232.892201            3419.420988
# std       2.873294               3079.573907            8136.256820
# min    2001.000000                  0.000000               0.000000
# 25%    2003.000000                 13.000000              45.000000
# 50%    2005.000000                113.000000             358.000000
# 75%    2008.000000                722.000000            1875.000000
# max    2010.000000              27960.000000           80663.000000
#
#        Value_of_Property_Recovered  Value_of_Property_Stolen
# count                 2.449000e+03              2.449000e+03
# mean                  5.859924e+07              2.465431e+08
# std                   2.494403e+08              9.670035e+08
# min                   0.000000e+00              0.000000e+00
# ...

# %%
data.isnull().sum()
# Out:
# Area_Name                      0
# Year                           0
# Group_Name                     0
# Sub_Group_Name                 0
# Cases_Property_Recovered       0
# Cases_Property_Stolen          0
# Value_of_Property_Recovered    0
# Value_of_Property_Stolen       0
# dtype: int64

# %%
data.Area_Name.value_counts()
# Out:
# Meghalaya                    70
# Goa                          70
# Bihar                        70
# Uttar Pradesh                70
# Madhya Pradesh               70
# Odisha                       70
# Mizoram                      70
# West Bengal                  70
# Uttarakhand                  70
# Nagaland                     70
# Daman & Diu                  70
# Gujarat                      70
# Kerala                       70
# Maharashtra                  70
# Chandigarh                   70
# Rajasthan                    70
# Jharkhand                    70
# Karnataka                    70
# Jammu & Kashmir              70
# Manipur                      70
# Dadra & Nagar Haveli         70
# Assam                        70
# Himachal Pradesh             70
# Tamil Nadu                   70
# Arunachal Pradesh            70
# Delhi                        70
# Tripura                      70
# Puducherry                   70
# Andaman & Nicobar Islands    70
# ...

# %%
data.Year.value_counts()
# Out:
# 2009    245
# 2005    245
# 2003    245
# 2001    245
# 2010    245
# 2008    245
# 2006    245
# 2004    245
# 2002    245
# 2007    244
# Name: Year, dtype: int64

# %%
data.Group_Name.value_counts()
# Out:
# Burglary - Property                    350
# Robbery - Property                     350
# Dacoity -Property                      350
# Theft - Property                       350
# Criminal Breach of Trust - Property    350
# Other heads of Property                350
# Total Property                         349
# Name: Group_Name, dtype: int64

# %%
data.Sub_Group_Name.value_counts()
# Out:
# 2. Robbery                              350
# 1. Dacoity                              350
# 4. Theft                                350
# 5. Criminal Breach of Trust             350
# 6. Other Property                       350
# 3. Burglary                             350
# 7. Total Property Stolen & Recovered    349
# Name: Sub_Group_Name, dtype: int64

# %% [raw]
# Group_Name and sub_group_name have same numbers of instances-lets check if sub_group_names belongs to same Group_Name so that any of them or Sub_Group_Name can be deleted from the Dataset

# %%
data.head(50)
# Out:
#                     Area_Name  Year           Group_Name Sub_Group_Name  \
# 0   Andaman & Nicobar Islands  2001  Burglary - Property    3. Burglary
# 1              Andhra Pradesh  2001  Burglary - Property    3. Burglary
# 2           Arunachal Pradesh  2001  Burglary - Property    3. Burglary
# 3                       Assam  2001  Burglary - Property    3. Burglary
# 4                       Bihar  2001  Burglary - Property    3. Burglary
# 5                  Chandigarh  2001  Burglary - Property    3. Burglary
# 6                Chhattisgarh  2001  Burglary - Property    3. Burglary
# 7        Dadra & Nagar Haveli  2001  Burglary - Property    3. Burglary
# 8                 Daman & Diu  2001  Burglary - Property    3. Burglary
# 9                       Delhi  2001  Burglary - Property    3. Burglary
# 10                        Goa  2001  Burglary - Property    3. Burglary
# 11                    Gujarat  2001  Burglary - Property    3. Burglary
# ...

# %%
a=data.groupby(['Group_Name']).get_group('Theft - Property')
a.Sub_Group_Name.value_counts()
# Out:
# 4. Theft    350
# Name: Sub_Group_Name, dtype: int64

# %%
b=data.groupby(['Group_Name']).get_group('Dacoity -Property')
b.Sub_Group_Name.value_counts()
# Out:
# 1. Dacoity    350
# Name: Sub_Group_Name, dtype: int64

# %%
c=data.groupby(['Group_Name']).get_group('Criminal Breach of Trust - Property')
c.Sub_Group_Name.value_counts()
# Out:
# 5. Criminal Breach of Trust    350
# Name: Sub_Group_Name, dtype: int64

# %%
d=data.groupby(['Group_Name']).get_group('Burglary - Property')
d.Sub_Group_Name.value_counts()
# Out:
# 3. Burglary    350
# Name: Sub_Group_Name, dtype: int64

# %%
e=data.groupby([ 'Group_Name']).get_group('Robbery - Property')
e.Sub_Group_Name.value_counts()
# Out:
# 2. Robbery    350
# Name: Sub_Group_Name, dtype: int64

# %%
f=data.groupby(['Group_Name']).get_group('Other heads of Property')
f.Sub_Group_Name.value_counts()
# Out:
# 6. Other Property    350
# Name: Sub_Group_Name, dtype: int64

# %%
g=data.groupby(['Group_Name']).get_group('Total Property')
g.Sub_Group_Name.value_counts()
# Out:
# 7. Total Property Stolen & Recovered    349
# Name: Sub_Group_Name, dtype: int64

# %% [raw]
# All the Sub_Group_Name are belongs to their corresponding Group_names so we delete the Sub_Group_Name column from the data set

# %%
data.drop(['Sub_Group_Name'],axis=1,inplace=True)
data
# Out:
#                       Area_Name  Year           Group_Name  \
# 0     Andaman & Nicobar Islands  2001  Burglary - Property
# 1                Andhra Pradesh  2001  Burglary - Property
# 2             Arunachal Pradesh  2001  Burglary - Property
# 3                         Assam  2001  Burglary - Property
# 4                         Bihar  2001  Burglary - Property
# ...                         ...   ...                  ...
# 2444                 Tamil Nadu  2010       Total Property
# 2445                    Tripura  2010       Total Property
# 2446              Uttar Pradesh  2010       Total Property
# 2447                Uttarakhand  2010       Total Property
# 2448                West Bengal  2010       Total Property
#
#       Cases_Property_Recovered  Cases_Property_Stolen  \
# 0                           27                     64
# 1                         3321                   7134
# 2                           66                    248
# ...

# %%
sns.barplot(x='Year',y='Value_of_Property_Stolen',data=data)
plt.show()

# %%
sns.barplot(x='Year',y='Value_of_Property_Recovered',data=data)
plt.show()

# %%
sns.barplot(y='Area_Name',x='Value_of_Property_Recovered',data=data)
plt.show()

# %%
property_bystate=data.groupby(['Area_Name'],as_index=False).sum()
sns.barplot(y='Area_Name',x='Value_of_Property_Recovered',data=property_bystate)
plt.show()

# %%
property_bystate=data.groupby(['Area_Name'],as_index=False).sum()
sns.barplot(y='Area_Name',x='Value_of_Property_Stolen',data=property_bystate)
plt.show()

# %%
property_bystate
# Out:
#                     Area_Name    Year  Cases_Property_Recovered  \
# 0   Andaman & Nicobar Islands  140385                      1516
# 1              Andhra Pradesh  140385                    332510
# 2           Arunachal Pradesh  140385                      6048
# 3                       Assam  140385                     54784
# 4                       Bihar  140385                     63876
# 5                  Chandigarh  140385                     15188
# 6                Chhattisgarh  140385                     68912
# 7        Dadra & Nagar Haveli  140385                      1170
# 8                 Daman & Diu  140385                       534
# 9                       Delhi  140385                    157858
# 10                        Goa  140385                      5884
# 11                    Gujarat  140385                    166644
# 12                    Haryana  140385                    133320
# 13           Himachal Pradesh  140385                      9798
# ...

# %%
property_bystate.drop(['Year'],axis=1,inplace=True)

# %%
property_bystate
# Out:
#                     Area_Name  Cases_Property_Recovered  \
# 0   Andaman & Nicobar Islands                      1516
# 1              Andhra Pradesh                    332510
# 2           Arunachal Pradesh                      6048
# 3                       Assam                     54784
# 4                       Bihar                     63876
# 5                  Chandigarh                     15188
# 6                Chhattisgarh                     68912
# 7        Dadra & Nagar Haveli                      1170
# 8                 Daman & Diu                       534
# 9                       Delhi                    157858
# 10                        Goa                      5884
# 11                    Gujarat                    166644
# 12                    Haryana                    133320
# 13           Himachal Pradesh                      9798
# 14            Jammu & Kashmir                     22718
# 15                  Jharkhand                     35368
# ...

# %%
sns.scatterplot(x='Value_of_Property_Recovered',y='Value_of_Property_Stolen',data=data)
plt.show()

# %%
property_bystate['Balance']=property_bystate['Value_of_Property_Stolen']-property_bystate['Value_of_Property_Recovered']
property_bystate
# Out:
#                     Area_Name  Cases_Property_Recovered  \
# 0   Andaman & Nicobar Islands                      1516
# 1              Andhra Pradesh                    332510
# 2           Arunachal Pradesh                      6048
# 3                       Assam                     54784
# 4                       Bihar                     63876
# 5                  Chandigarh                     15188
# 6                Chhattisgarh                     68912
# 7        Dadra & Nagar Haveli                      1170
# 8                 Daman & Diu                       534
# 9                       Delhi                    157858
# 10                        Goa                      5884
# 11                    Gujarat                    166644
# 12                    Haryana                    133320
# 13           Himachal Pradesh                      9798
# 14            Jammu & Kashmir                     22718
# 15                  Jharkhand                     35368
# ...

# %%
property_bystate['Percentage_of_recovery']=(property_bystate.Value_of_Property_Recovered/property_bystate.Value_of_Property_Stolen)*100
property_bystate
# Out:
#                     Area_Name  Cases_Property_Recovered  \
# 0   Andaman & Nicobar Islands                      1516
# 1              Andhra Pradesh                    332510
# 2           Arunachal Pradesh                      6048
# 3                       Assam                     54784
# 4                       Bihar                     63876
# 5                  Chandigarh                     15188
# 6                Chhattisgarh                     68912
# 7        Dadra & Nagar Haveli                      1170
# 8                 Daman & Diu                       534
# 9                       Delhi                    157858
# 10                        Goa                      5884
# 11                    Gujarat                    166644
# 12                    Haryana                    133320
# 13           Himachal Pradesh                      9798
# 14            Jammu & Kashmir                     22718
# 15                  Jharkhand                     35368
# ...

# %%
property_bystate.Percentage_of_recovery.sort_values()
# Out:
# 9      4.575912
# 24     5.951791
# 10     7.890197
# 0      8.292146
# 29     8.412347
# 21     9.556621
# 22    10.224391
# 11    10.389920
# 17    11.100266
# 7     11.217637
# 20    12.298915
# 31    13.941511
# 4     14.555056
# 15    14.783706
# 18    16.134099
# 25    21.237900
# 8     21.728024
# 34    22.113233
# 13    25.189368
# 3     26.157381
# 33    30.668357
# 16    30.916216
# 6     33.490224
# 2     34.113572
# 5     37.346324
# 14    39.774449
# 23    40.082484
# 1     44.348162
# 26    54.904639
# 27    55.165961
# 28    57.077204
# 32    58.177294
# 12    58.925077
# 30    62.178977
# 19    65.482590
# Name: Percentage_of_recovery, dtype: float64

# %%
property_bystate.Percentage_of_recovery.mean()
# Out:
# 27.954341563605634

# %% [raw]
# The mean of  percentage of Recovery of Values of States are 27.954341563605634.
#
# Madhya Pradesh has highest and Delhi has lowest rate of Recovery of Stolen Item Values 65.482590 % and 4.575912 % respectively.
